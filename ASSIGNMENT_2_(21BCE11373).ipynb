# %% [markdown]
# # assignment 2 ( applied data science - 21BCE11373 )

# %% [markdown]
# # task 1 done ; task 2 :-

# %%
import pandas as pd

# Load the dataset from the Excel file
df = pd.read_excel('House Price India.xlsx')  

df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %% [markdown]
# # task 3

# %% [markdown]
# # uni variate visualization

# %%
import matplotlib.pyplot as plt

#histogram

plt.hist(df['Built Year'], bins=10)  
plt.xlabel('year ')
plt.ylabel('no. of houses ')
plt.title('Histogram of Built Year')
plt.show()

# %%
# Scatter plot

plt.scatter(df['living area'], df['lot area'])
plt.xlabel('living area')
plt.ylabel('lot area')
plt.title('Scatter Plot of living area vs. lot area')
plt.show()

# %% [markdown]
# # multi variate analysis

# %%
from mpl_toolkits.mplot3d import Axes3D

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = df['number of bedrooms']
y = df['number of bathrooms']
z = df['number of floors']

ax.scatter(x, y, z, c='b', marker='o')

ax.set_xlabel('number of bedrooms')
ax.set_ylabel('number of bathrooms')
ax.set_zlabel('number of floors')

plt.title('3D Scatter Plot')
plt.show()

# %% [markdown]
# # task 4 : Perform Descriptive Statistics

# %%
descriptive_stats = df.describe()
print(descriptive_stats)
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %% [markdown]
# # task 5 : Handle Missing Values

# %%
# Check for missing values
missing_values = df.isna()

# Fill missing values with the mean of each column
df.fillna(df.mean(), inplace=True)

# Drop rows with missing values
df.dropna(inplace=True)
